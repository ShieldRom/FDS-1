# %% [markdown]
# Data Preprocessing and Data Transformation

# %%
import pandas as pd
import numpy as np
cols=['col0', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6']
rows=['row0', 'row1', 'row2', 'row3', 'row4', 'row5', 'row6']
data=np.random.randint(100, 300, size=(7,7))
df=pd.DataFrame(data, columns=cols, index=rows)
df.head()
# Out:
#       col0  col1  col2  col3  col4  col5  col6
# row0   197   182   169   152   235   274   147
# row1   145   125   111   136   285   101   181
# row2   233   170   294   194   141   256   197
# row3   143   233   290   256   286   143   297
# row4   187   144   164   119   183   119   250

# %%
df['col1']['row1']
# Out:
# 125

# %%
df.iloc[4, 2]
# Out:
# 164

# %%
df.loc['row4','col2']
# Out:
# 164

# %%
df_new=df[['col1', 'col2']]
df_new.head()
# Out:
#       col1  col2
# row0   182   169
# row1   125   111
# row2   170   294
# row3   233   290
# row4   144   164

# %%
df_new=df[['col1', 'col2']][1:4]
df_new.head(3)
# Out:
#       col1  col2
# row1   125   111
# row2   170   294
# row3   233   290

# %%
df['col0']
df.loc[:,'col0']
df.iloc[:, 0]
# Out:
# row0    197
# row1    145
# row2    233
# row3    143
# row4    187
# row5    102
# row6    198
# Name: col0, dtype: int64

# %%
df['col3'][2:5]
# Out:
# row2    194
# row3    256
# row4    119
# Name: col3, dtype: int64

# %%
df.loc['row1': 'row4',:]
# Out:
#       col0  col1  col2  col3  col4  col5  col6
# row1   145   125   111   136   285   101   181
# row2   233   170   294   194   141   256   197
# row3   143   233   290   256   286   143   297
# row4   187   144   164   119   183   119   250

# %%
df.iloc[1:4, :]
# Out:
#       col0  col1  col2  col3  col4  col5  col6
# row1   145   125   111   136   285   101   181
# row2   233   170   294   194   141   256   197
# row3   143   233   290   256   286   143   297

# %%
df.loc[:,'clo1': 'col4']
# Out:
#       col0  col1  col2  col3  col4
# row0   197   182   169   152   235
# row1   145   125   111   136   285
# row2   233   170   294   194   141
# row3   143   233   290   256   286
# row4   187   144   164   119   183
# row5   102   113   195   210   260
# row6   198   190   165   102   233

# %%
df.iloc[:, 1:4]
# Out:
#       col1  col2  col3
# row0   182   169   152
# row1   125   111   136
# row2   170   294   194
# row3   233   290   256
# row4   144   164   119
# row5   113   195   210
# row6   190   165   102

# %%
df.loc['row1':'row4', 'col1':'col4']
# Out:
#       col1  col2  col3  col4
# row1   125   111   136   285
# row2   170   294   194   141
# row3   233   290   256   286
# row4   144   164   119   183

# %%
df.iloc[1:4,1:4]
# Out:
#       col1  col2  col3
# row1   125   111   136
# row2   170   294   194
# row3   233   290   256

# %%
df.loc['row2':'row4', ['col1', 'col3']]
# Out:
#       col1  col3
# row2   170   194
# row3   233   256
# row4   144   119

# %%
df.dropna(how="all", axis=1)
# Out:
#       col0  col1  col2  col3  col4  col5  col6
# row0   197   182   169   152   235   274   147
# row1   145   125   111   136   285   101   181
# row2   233   170   294   194   141   256   197
# row3   143   233   290   256   286   143   297
# row4   187   144   164   119   183   119   250
# row5   102   113   195   210   260   173   126
# row6   198   190   165   102   233   143   223
